# %%
import nltk
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
import unidecode
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import itertools

# %%
# print(stopwords.words('spanish'))
encuesta = pd.read_csv('encuesta.csv')
# tweets["date"] = tweets.apply(lambda row: row["date"].split(" ")[0], axis=1)
encuesta.head()
# Out:
#     Ciudad   Estado    Pais  Codigo Postal Genero/Sexo Estado Civil  Edad  \
# 0  Durango  Durango  Mexico          34200      Hombre      Soltero    22
# 1  Durango  Durango  Mexico          34200       Mujer      Soltero    22
# 2  Durango  Durango  Mexico          34200       Mujer      Soltero    22
# 3  Durango  Durango  Mexico          34782       Mujer       Casado    21
# 4  Durango  Durango  Mexico          34582      Hombre        Viudo    26
#
#    Año de nacimiento Nivel de estudios      area_profesion_carrera  ...  \
# 0               2000       Profesional  Tecnologias de informacion  ...
# 1               2000       Profesional  Tecnologias de informacion  ...
# 2               2000       Profesional  Tecnologias de informacion  ...
# 3               2001       Profesional  Filosofía, idioma y letras  ...
# 4               1996   Carrera técnica                   Otra Área  ...
#
#   Pasar más tiempo con mi familia, amigos, seres queridos  \
# ...

# %% [markdown]
# Elaboración de Gráficas en Python con valores medios, considerando hombres y mujeres por separado.

# %%
# Grafica de promedios para hombres y mujeres
# encuesta.columns[11:61]
for col in encuesta.columns[11:61]:
    sns.boxplot(y=col,
                x='Genero/Sexo',
                showmeans=True,
                meanprops={
                            "markerfacecolor":"white", 
                            "markeredgecolor":"black",
                            "markersize":"10"},
                data=encuesta)
    plt.xlabel("Genero/Sexo", size=14)
    plt.ylabel("1 < Menos de acuerdo | Mas de acuerdo > 10", size=14)
    plt.title(col, size=14)
    plt.show()
